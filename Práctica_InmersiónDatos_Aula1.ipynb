# %% [markdown]
# <a href="https://colab.research.google.com/github/IAferaboli/InmersionDatos_AluraLatam/blob/main/Pr%C3%A1ctica_Inmersi%C3%B3nDatos_Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1
# #Inicios en pandas y DataFrama Inmuebles Bogotá

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmuebles.shape #devuelve cantidad de filas, columnas de la base importada
# Out:
# (9520, 8)

# %%
inmuebles.columns #devuelve objeto con las columnas de la base de datos
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
#cambiamos nombre de las columnas
columnas = {'Baños':'Banos', 'Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
#devolvemos 10 ejemplos aleatorios
inmuebles.sample(10)
# Out:
#              Tipo                                  Descripcion  Habitaciones  \
# 3646         Casa              Casa en venta en Ciudad Bolívar             2
# 8046  Apartamento             Apartamento en venta en Fontibón             3
# 1786  Apartamento      Apartamento en venta en Chico Reservado             2
# 5711  Apartamento   Apartamento en venta en Zona Noroccidental             3
# 6414  Apartamento      Apartamento en venta en Chico Reservado             3
# 7312         Casa                     Casa en venta en Tintala             3
# 177   Apartamento  Apartamento en venta en Candelaria La Nueva             3
# 3596  Apartamento   Apartamento en venta en Zona Noroccidental             3
# 6384  Apartamento              Apartamento en venta en Mazuren             3
# 398   Apartamento             Apartamento en venta en Cedritos             2
#
#       Banos  Area               Barrio  \
# 3646      1    53       Ciudad Bolívar
# 8046      2    57             Fontibón
# 1786      2   119      Chico Reservado
# 5711      2    70   Zona Noroccidental
# 6414      3   120      Chico Reservado
# 7312      2    72              Tintala
# 177       1    54  Candelaria La Nueva
# 3596      2    88   Zona Noroccidental
# 6384      2   120              Mazuren
# 398       2    63             Cedritos
#
#                                                     UPZ            Valor
# 3646  CIUDAD BOLÍVAR: Monteblanco + El Tesoro + El M...    $ 140.000.000
# 8046                                           Fontibón    $ 170.000.000
# 1786                 CHAPINERO: Chicó Lago + El Refugio  $ 1.385.733.652
# 5711                 CHAPINERO: Pardo Rubio + Chapinero    $ 332.808.000
# 6414                 CHAPINERO: Chicó Lago + El Refugio    $ 750.000.000
# 7312                                            Tintala    $ 210.000.000
# 177                                       La Candelaria    $ 140.000.000
# 3596                 CHAPINERO: Pardo Rubio + Chapinero    $ 500.000.000
# 6384                                           El Prado    $ 390.000.000
# 398                                             Usaquén    $ 330.000.000

# %%
#obtener información del dataset
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
#devuelve info del [índice] indicado
inmuebles.iloc[35]
# Out:
# Tipo                                           Apartamento
# Descripcion     Apartamento en venta en Zona Noroccidental
# Habitaciones                                             2
# Banos                                                    2
# Area                                                    45
# Barrio                                  Zona Noroccidental
# UPZ                     CHAPINERO: Pardo Rubio + Chapinero
# Valor                                        $ 129.000.000
# Name: 35, dtype: object

# %%
#devuelve rando de registros hasta, no incluye
inmuebles.iloc[48:54]
# Out:
#            Tipo                                 Descripcion  Habitaciones  \
# 48  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 49  Apartamento            Apartamento en venta en Castilla             3
# 50  Apartamento            Apartamento en venta en Cedritos             2
# 51  Apartamento             Apartamento en venta en Mazuren             3
# 52  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 53  Apartamento            Apartamento en venta en Fontibón             3
#
#     Banos  Area              Barrio                                 UPZ  \
# 48      2    78  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 49      2    68            Castilla         KENNEDY: Castilla + Bavaria
# 50      2    79            Cedritos                             Usaquén
# 51      3    92             Mazuren                            El Prado
# 52      2    88  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 53      2    84            Fontibón                            Fontibón
#
#             Valor
# 48  $ 259.000.000
# 49  $ 310.000.000
# 50  $ 354.000.000
# 51  $ 372.000.000
# 52  $ 500.000.000
# 53  $ 420.000.000

# %%
#devuelve la info de la ['columna'] ingresada
inmuebles['Descripcion'][369:375]
# Out:
# 369     Apartamento en venta en Kennedy
# 370     Apartamento en venta en Mazuren
# 371        Apartamento en venta en Bosa
# 372    Apartamento en venta en Cedritos
# 373    Apartamento en venta en Fontibón
# 374        Apartamento en venta en Bosa
# Name: Descripcion, dtype: object

# %%
#promedio de área
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
#Entre () devuelve un pandas serie (True/False)
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
#.value_counts() devuelve conteo de valores en base al atributo nombrado
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
inmuebles.UPZ.value_counts()
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %%
#Tarea/desafío
#Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.

inmuebles_por_barrio = inmuebles.groupby(['Barrio'])[['Area']].sum()
inmuebles_por_barrio

inmuebles_por_barrio.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# # Aula 2
# #Solución a desafíos, Intro a Seaborm y Matploitlib

# %%
#separamos el dato str en dos nuevas columnas
valor= inmuebles.Valor.str.split(expand= True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]

# %%
#quitamos el . para obtener un str neto de números
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.', '', regex= True)

# %%
#transformamos el dataframe a float para poder manipularlo matemáticamente
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000

# %%
#de manera rápida visualizar media, mediana, max, min, quartiles
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
#Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.
precio_max = inmuebles['Precio_Millon'].max()
print('El precio máximo es ', precio_max)
# Out:
# El precio máximo es  16000.0

# %%
precio_min = inmuebles['Precio_Millon'].min()
print('El precio mínimo es ', precio_min)
# Out:
# El precio mínimo es  60.0

# %%
area_min = inmuebles['Area'].min()
print('El área mínima es de ', area_min, 'mts2')
# Out:
# El área mínima es de  2 mts2

# %%
area_max = inmuebles['Area'].max()
print('El área máxima es de ', area_max, 'mts2')
# Out:
# El área máxima es de  166243 mts2

# %%
#localizar un dato en particular
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))

grafica=sns.histplot(data=inmuebles, x='Precio_Millon', kde= True, hue='Tipo')
grafica.set_title('Distribución de Valores de inmuebles, Bogotá')
plt.xlim((50, 1000))
plt.savefig('/content/drive/MyDrive/InmersiónDatos/ValorInmuebles.png', format= 'png')
plt.show()

# %%
#Desafío clase 2
#Seleccionar y comparar Fincas, apartamentos y Bodegas
#Refinar gráfico (estético)
#Realizar una conclusión a partir de ello

tipo_inmueble= inmuebles.Tipo.value_counts()
tipo_inmueble
# Out:
# Apartamento            7327
# Casa                   2043
# Oficina/Consultorio      60
# Local                    38
# Edificio                 22
# Bodega                   13
# Finca                    11
# Lote                      6
# Name: Tipo, dtype: int64

# %% [markdown]
# #Aula 3
# #Solución desafíos, cierre DataFrame Inmobiliaria - Introducción DataFrame DANE

# %%
#Solución Alura

inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.Valor_m2_Millon.head(3)
# Out:
# 0   5.14
# 1   3.94
# 2   7.78
# Name: Valor_m2_Millon, dtype: float64

# %%
#Calcular precio por mt2 y graficar (el más adecuado) para esta nueva variable

area_total= inmuebles.Area.sum()
area_total

precio_millon_total = inmuebles.Precio_Millon.sum()
precio_millon_total

promedio_precio_mts2 = precio_millon_total/area_total
print('El costo promedio de mts2 es de ', promedio_precio_mts2)
# Out:
# El costo promedio de mts2 es de  4.105025472253497

# %%
inmuebles.groupby(['Barrio']).mean()

datos_barrios= inmuebles.groupby(['Barrio']).sum()
datos_barrios['Valor_m2_barrio'] = datos_barrios['Precio_Millon']/datos_barrios['Area']
datos_barrios
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon  Valor_m2_barrio
# Barrio
# Alameda                        5.98             5.98
# Alhambra                      73.56             3.95
# Andes Norte                   42.35             5.68
# Antonio Nariño               169.47             2.82
# Barrancas                     66.24             4.47
# ...                             ...              ...
# Villa Maria                   26.58             1.94
# Villas De Granada             69.71             3.26
# Villemar                      71.81             3.95
# Zona Franca                    2.96             2.96
# Zona Noroccidental          4049.16             4.57
#
# [149 rows x 6 columns]

# %%
m2_barrio = dict(datos_barrios['Valor_m2_barrio'])

inmuebles['Valor_m2_barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_barrio'] = inmuebles['Valor_m2_barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon  \
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78
# 3    $ 890.000.000      $   890000000         890.00             5.78
# 4    $ 970.000.000      $   970000000         970.00             7.58
#
#    Valor_m2_barrio
# 0             4.57
# 1             3.40
# 2             8.10
# 3             5.66
# 4             6.29

# %%
#devuelve top valores
inmuebles['Barrio'].value_counts()[:10].index
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
#reseteamos index para que 'Barrio' pase a ser columna y no index
top_barrios= inmuebles['Barrio'].value_counts()[:10].index
datos_barrios.reset_index(inplace=True)
datos_barrios
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_barrio
# 0               5.98             5.98
# 1              73.56             3.95
# 2              42.35             5.68
# 3             169.47             2.82
# 4              66.24             4.47
# ..               ...              ...
# 144            26.58             1.94
# 145            69.71             3.26
# 146            71.81             3.95
# 147             2.96             2.96
# 148          4049.16             4.57
#
# [149 rows x 7 columns]

# %%
#devuleve la consulta realizada con query
datos_barrios.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# 50           1795.71             2.89
# 63           2127.66             3.38
# 125          2701.88             5.85
# 132          2000.72             4.32
# 138          6334.04             5.66
# 148          4049.16             4.57

# %%
plt.figure(figsize=(8, 6))
ax = sns.barplot(x='Barrio', y= 'Valor_m2_barrio', data= datos_barrios.query('Barrio in @top_barrios'))
ax.tick_params(axis= 'x', rotation = 45)

# %%
plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='Barrio', y= 'Valor_m2_Millon', data= inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis= 'x', rotation = 45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='Barrio', y= 'Valor_m2_Millon', data= inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis= 'x', rotation = 45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.boxplot(x='Barrio', y= 'Precio_Millon', data= inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis= 'x', rotation = 45)
plt.show()

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/Identificación (Capítulo A).csv', sep= ';', encoding='latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# 1                            Santa Isabel  17,8555889419101
# 2  SANTA FE: Las Nieves + Sagrado Corazón  10,0286103658331
# 3   USAQUÉN: Country Club + Santa Bárbara  28,6502122142802
# 4   USAQUÉN: Country Club + Santa Bárbara  24,4684068319009

# %%
#conocer el tamaño del DataSet
datos_raw.shape
# Out:
# (106467, 11)

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/Datos de la vivenda y su entorno (Capítulo B).csv', sep=';', encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/Condiciones habitacionales del hogar (Capítulo C).csv', sep=';', encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/Composición del hogar y demografía (Capítulo E).csv', sep=';', encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/Educación (Capítulo H).csv', sep=';', encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep=';', encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/Fuerza de trabajo (Capítulo K).csv', sep=';', encoding='latin-1')
# Out:
# <ipython-input-46-2282a5c8028b>:2: DtypeWarning: Columns (25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/Condiciones habitacionales del hogar (Capítulo C).csv', sep=';', encoding='latin-1')
# <ipython-input-46-2282a5c8028b>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/Educación (Capítulo H).csv', sep=';', encoding='latin-1')
# <ipython-input-46-2282a5c8028b>:5: DtypeWarning: Columns (117,122,164,166,168) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_l = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep=';', encoding='latin-1')
# <ipython-input-46-2282a5c8028b>:6: DtypeWarning: Columns (27,58,60,62,64,104,120,124,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_k = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/Fuerza de trabajo (Capítulo K).csv', sep=';', encoding='latin-1')

# %%
datos_dane = pd.merge(datos_raw, datos_b, on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane, datos_c, on='DIRECTORIO', how='left')

# %%
datos_dane = pd.merge(datos_dane, datos_e, on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-49-31131df05887>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane, datos_e, on='DIRECTORIO', how='left')
# (108696, 281)

# %%
#datos_dane = pd.merge(datos_dane, datos_h, on='DIRECTORIO', how='left')

# %%
#datos_dane = pd.merge(datos_dane, datos_l, on='DIRECTORIO', how='left')

# %%
#datos_dane = pd.merge(datos_dane, datos_k, on='DIRECTORIO', how='left')
#datos_dane.shape

# %%
datos_dane.info
# Out:
# <bound method DataFrame.info of         DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0       3004346.00    11  11001      1           3.00         Santa Fe
# 1       3004347.00    11  11001      1          14.00     Los Mártires
# 2       3004348.00    11  11001      1           3.00         Santa Fe
# 3       3004349.00    11  11001      1           1.00          Usaquén
# 4       3004350.00    11  11001      1           1.00          Usaquén
# ...            ...   ...    ...    ...            ...              ...
# 108691  3004341.00    11  11001      1           3.00         Santa Fe
# 108692  3004342.00    11  11001      1           3.00         Santa Fe
# 108693  3004343.00    11  11001      1          14.00     Los Mártires
# 108694  3004344.00    11  11001      1           3.00         Santa Fe
# 108695  3004345.00    11  11001      1           3.00         Santa Fe
#
#         COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0              814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1               37.00                            Santa Isabel     11001162
# 2              814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3              803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4              803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# ...               ...                                     ...          ...
# 108691         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 108692         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 108693          37.00                            Santa Isabel     11001162
# 108694         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 108695         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
#
#                                 NOMBRE_ESTRATO  ... NPCEP22A  NPCEP24  \
# 0       SANTA FE: Las Nieves + Sagrado Corazón  ...      NaN      NaN
# 1                                 Santa Isabel  ...      NaN      NaN
# 2       SANTA FE: Las Nieves + Sagrado Corazón  ...      NaN      NaN
# 3        USAQUÉN: Country Club + Santa Bárbara  ...      NaN      NaN
# 4        USAQUÉN: Country Club + Santa Bárbara  ...      NaN      NaN
# ...                                        ...  ...      ...      ...
# 108691  SANTA FE: Las Nieves + Sagrado Corazón  ...      NaN      NaN
# 108692  SANTA FE: Las Nieves + Sagrado Corazón  ...      NaN      NaN
# 108693                            Santa Isabel  ...      NaN      NaN
# 108694  SANTA FE: Las Nieves + Sagrado Corazón  ...      NaN      NaN
# 108695  SANTA FE: Las Nieves + Sagrado Corazón  ...      NaN      NaN
#
#         NPCEP24A  NPCEP25  NPCEP25A  NPCEP27  NPCEP26  NPCEP29  NPCEP29A  \
# 0            NaN      NaN       NaN      NaN      NaN      NaN       NaN
# 1            NaN      NaN       NaN      NaN      NaN      NaN       NaN
# 2            NaN      NaN       NaN      NaN      NaN      NaN       NaN
# 3            NaN      NaN       NaN      NaN      NaN      NaN       NaN
# 4            NaN      NaN       NaN      NaN      NaN      NaN       NaN
# ...          ...      ...       ...      ...      ...      ...       ...
# 108691       NaN      NaN       NaN      NaN      NaN      NaN       NaN
# 108692       NaN      NaN       NaN      NaN      NaN      NaN       NaN
# 108693       NaN      NaN       NaN      NaN      NaN      NaN       NaN
# 108694       NaN      NaN       NaN      NaN      NaN      NaN       NaN
# 108695       NaN      NaN       NaN      NaN      NaN      NaN       NaN
#
#         FEX_C_y
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 108691      NaN
# 108692      NaN
# 108693      NaN
# 108694      NaN
# 108695      NaN
#
# [108696 rows x 281 columns]>

# %% [markdown]
# # Aula 4
# #Trabajando con merge de datos

# %%
#importamos .csv ya tratado por Alura
datos_dane = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/datos_dane.csv')
datos_dane.head
# Out:
# <bound method NDFrame.head of       DIRECTORIO NOMBRE_LOCALIDAD  \
# 0     3004368.00          Usaquén
# 1     3004369.00          Usaquén
# 2     3004375.00        Chapinero
# 3     3004380.00          Usaquén
# 4     3004383.00         Fontibón
# ...          ...              ...
# 9852  3004289.00         Santa Fe
# 9853  3004294.00         Santa Fe
# 9854  3004303.00         Santa Fe
# 9855  3004328.00         Santa Fe
# 9856  3004338.00     Los Mártires
#
#                                      NOMBRE_ESTRATO  NVCBP4  NVCBP14A  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe       1         2
# 1                                           Usaquén       1         2
# 2                CHAPINERO: Pardo Rubio + Chapinero       2         2
# 3                                        Los Cedros       1         2
# 4                         Ciudad Salitre Occidental       1         2
# ...                                             ...     ...       ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón       1         2
# 9853         SANTA FE: Las Nieves + Sagrado Corazón       2         2
# 9854         SANTA FE: Las Nieves + Sagrado Corazón       1         2
# 9855         SANTA FE: Las Nieves + Sagrado Corazón       1         2
# 9856                                   Santa Isabel       2         1
#
#       NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  NHCLP5  NHCLP8AB  \
# 0            2         2         2         2         2  ...       1       NaN
# 1            2         2         2         2         2  ...       2       NaN
# 2            2         2         2         2         1  ...       2       NaN
# 3            2         2         2         2         2  ...       1       NaN
# 4            2         2         2         1         2  ...       2       NaN
# ...        ...       ...       ...       ...       ...  ...     ...       ...
# 9852         2         2         2         1         1  ...       1       NaN
# 9853         2         1         2         1         1  ...       2       NaN
# 9854         2         2         2         2         2  ...       1       NaN
# 9855         2         2         2         2         2  ...       1       NaN
# 9856         2         2         1         2         1  ...       1       NaN
#
#       NHCLP8AE  NHCLP10  NHCLP11  NHCLP29_1A  NHCLP29_1C  NHCLP29_1E  \
# 0          NaN        2        2         NaN         NaN         NaN
# 1          NaN        3        2         NaN         NaN         NaN
# 2          NaN        2        2         NaN         NaN        1.00
# 3          NaN        3        2         NaN         NaN         NaN
# 4          NaN        2        2         NaN         NaN         NaN
# ...        ...      ...      ...         ...         ...         ...
# 9852       NaN        3        2         NaN         NaN         NaN
# 9853       NaN        2        2         NaN         NaN         NaN
# 9854       NaN        3        2         NaN         NaN         NaN
# 9855       NaN        3        2         NaN         NaN         NaN
# 9856       NaN        2        2         NaN         NaN         NaN
#
#       NHCLP29_1F  NPCHP4
# 0            NaN    9.00
# 1            NaN   11.00
# 2            NaN   11.00
# 3            NaN    9.00
# 4            NaN   11.00
# ...          ...     ...
# 9852         NaN   13.00
# 9853         NaN    9.00
# 9854         NaN    9.00
# 9855         NaN   11.00
# 9856         NaN    7.00
#
# [9857 rows x 55 columns]>

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
#  16  NPCKP23           9558 non-null   float64
#  17  NPCKP44A          9857 non-null   float64
#  18  NPCKPN62A         9857 non-null   float64
#  19  NPCKPN62B         9558 non-null   float64
#  20  NPCKP64A          9857 non-null   int64
#  21  NPCKP64E          9857 non-null   int64
#  22  NHCCP3            9857 non-null   float64
#  23  NHCCP6            9857 non-null   float64
#  24  NHCCP7            9558 non-null   float64
#  25  NHCCP8_1          1434 non-null   float64
#  26  NHCCP8_2          1434 non-null   float64
#  27  NHCCP8_3          1434 non-null   float64
#  28  NHCCP8_6          1434 non-null   float64
#  29  NHCCP8_7          1434 non-null   float64
#  30  NHCCP8_8          1434 non-null   float64
#  31  NHCCP8_9          1434 non-null   float64
#  32  NHCCP9            9558 non-null   float64
#  33  NHCCP11           9857 non-null   int64
#  34  NHCCP11A          1177 non-null   float64
#  35  NHCCP12           8680 non-null   float64
#  36  NHCCP41           9857 non-null   int64
#  37  NHCCP41A          4987 non-null   float64
#  38  NHCCP47A          9857 non-null   int64
#  39  NHCCP47B          9857 non-null   int64
#  40  NHCLP2A           9857 non-null   int64
#  41  NHCLP2B           9857 non-null   int64
#  42  NHCLP2C           9857 non-null   int64
#  43  NHCLP2E           9857 non-null   int64
#  44  NHCLP4            9857 non-null   int64
#  45  NHCLP5            9857 non-null   int64
#  46  NHCLP8AB          288 non-null    float64
#  47  NHCLP8AE          288 non-null    float64
#  48  NHCLP10           9857 non-null   int64
#  49  NHCLP11           9857 non-null   int64
#  50  NHCLP29_1A        410 non-null    float64
#  51  NHCLP29_1C        143 non-null    float64
#  52  NHCLP29_1E        1272 non-null   float64
#  53  NHCLP29_1F        152 non-null    float64
#  54  NPCHP4            9447 non-null   float64
# dtypes: float64(28), int64(25), object(2)
# memory usage: 4.1+ MB

# %%
#Diccionario de trabajo provisto por Alura, cambia los códigos de columna por nombres referentes
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO', 
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES', 
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES', 
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA', 
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19', 
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA', 
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO', 
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA', 
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO', 
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO', 
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane)
datos_dane.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
#        'SON_INGRESOS_SUFICIENTES', 'SE_CONSIDERA_POBRE', 'MED_C19_TRABAJO',
#        'MED_C19_CAMBIO_VIVIENDA', 'MED_C19_ENDEUDAMIENTO',
#        'MED_C19_VENTA_BIENES', 'NIVEL_EDUCATIVO'],
#       dtype='object')

# %%
datos_dane.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO', 'INSEGURIDAD', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO', 'BASURA_INADECUADA', 'RUIDO', 'SALARIO_MES', 'TIENE_ESCRITURA']].mean().head()
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
#                                                   BARES_DISCO  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.89
# Américas                                                 1.79
# Apogeo                                                   1.94
# Arborizadora                                             1.88
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.98
#
#                                                   OSCURO_PELIGROSO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.84
# Américas                                                      1.92
# Apogeo                                                        2.00
# Arborizadora                                                  1.84
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.87
#
#                                                   BASURA_INADECUADA  RUIDO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                    1.72   1.56
# Américas                                                       1.93   1.61
# Apogeo                                                         1.84   1.68
# Arborizadora                                                   1.86   1.69
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre               1.93   1.70
#
#                                                   SALARIO_MES  TIENE_ESCRITURA
# NOMBRE_ESTRATO
# 20 de Julio                                        1493859.61             1.16
# Américas                                           2672138.14             1.06
# Apogeo                                             1837583.18             1.08
# Arborizadora                                       1802296.76             1.03
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre   2943730.73             1.05

# %%
datos = datos_dane[['NOMBRE_ESTRATO', 'CONJUNTO_CERRADO', 'INSEGURIDAD', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO', 'BASURA_INADECUADA', 'RUIDO', 'SALARIO_MES', 'TIENE_ESCRITURA']].replace(2, 0)

# %%
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO', 'INSEGURIDAD', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO', 'BASURA_INADECUADA', 'RUIDO', 'SALARIO_MES', 'TIENE_ESCRITURA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              0.81            0.15
# Américas                                                 0.75            0.02
# Apogeo                                                   0.70            0.25
# Arborizadora                                             0.70            0.05
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         0.67            0.01
# ...                                                       ...             ...
# Usaquén                                                  0.22            0.01
# Venecia                                                  0.82            0.24
# Verbenal                                                 0.56            0.08
# Zona Franca                                              0.50            0.09
# Álamos                                                   0.83            0.19
#
#                                                   BARES_DISCO  \
# NOMBRE_ESTRATO
# 20 de Julio                                              0.11
# Américas                                                 0.21
# Apogeo                                                   0.06
# Arborizadora                                             0.12
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         0.02
# ...                                                       ...
# Usaquén                                                  0.03
# Venecia                                                  0.29
# Verbenal                                                 0.03
# Zona Franca                                              0.05
# Álamos                                                   0.01
#
#                                                   OSCURO_PELIGROSO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.16
# Américas                                                      0.08
# Apogeo                                                        0.00
# Arborizadora                                                  0.16
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.13
# ...                                                            ...
# Usaquén                                                       0.01
# Venecia                                                       0.36
# Verbenal                                                      0.14
# Zona Franca                                                   0.31
# Álamos                                                        0.28
#
#                                                   BASURA_INADECUADA  RUIDO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                    0.28   0.44
# Américas                                                       0.07   0.39
# Apogeo                                                         0.16   0.32
# Arborizadora                                                   0.14   0.31
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre               0.07   0.30
# ...                                                             ...    ...
# Usaquén                                                        0.02   0.20
# Venecia                                                        0.35   0.50
# Verbenal                                                       0.11   0.25
# Zona Franca                                                    0.11   0.31
# Álamos                                                         0.34   0.65
#
#                                                   SALARIO_MES  TIENE_ESCRITURA
# NOMBRE_ESTRATO
# 20 de Julio                                        1493859.61             0.84
# Américas                                           2672138.14             0.94
# Apogeo                                             1837583.18             0.92
# Arborizadora                                       1802296.76             0.97
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre   2943730.73             0.95
# ...                                                       ...              ...
# Usaquén                                            4670896.88             0.97
# Venecia                                            2078712.71             0.83
# Verbenal                                           2445403.14             0.87
# Zona Franca                                        1508602.98             0.94
# Álamos                                             2897865.04             0.93
#
# [102 rows x 9 columns]

# %%
datos_ml = pd.merge(inmuebles, datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tipo               9520 non-null   object
#  1   Descripcion        9520 non-null   object
#  2   Habitaciones       9520 non-null   int64
#  3   Banos              9520 non-null   int64
#  4   Area               9520 non-null   int64
#  5   Barrio             9520 non-null   object
#  6   UPZ                9478 non-null   object
#  7   Valor              9520 non-null   object
#  8   Moneda             9520 non-null   object
#  9   Precio             9520 non-null   object
#  10  Precio_Millon      9520 non-null   float64
#  11  Valor_m2_Millon    9520 non-null   float64
#  12  Valor_m2_barrio    9520 non-null   float64
#  13  CONJUNTO_CERRADO   9366 non-null   float64
#  14  INSEGURIDAD        9366 non-null   float64
#  15  TERMINALES_BUS     9366 non-null   float64
#  16  BARES_DISCO        9366 non-null   float64
#  17  OSCURO_PELIGROSO   9366 non-null   float64
#  18  BASURA_INADECUADA  9366 non-null   float64
#  19  RUIDO              9366 non-null   float64
#  20  SALARIO_MES        9366 non-null   float64
#  21  TIENE_ESCRITURA    9366 non-null   float64
# dtypes: float64(12), int64(3), object(7)
# memory usage: 1.7+ MB

# %%
upz = pd.read_csv('/content/drive/MyDrive/InmersiónDatos/cod_upz.csv')
datos_ml = pd.merge(datos_ml, upz, left_on= 'UPZ', right_on= 'NOMBRE_ESTRATO', how='inner')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 2            Casa         Casa en venta en Zona Noroccidental             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4            Casa         Casa en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
#       Banos  Area              Barrio                                 UPZ  \
# 0         2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1         3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2         4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3         1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4         6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# ...     ...   ...                 ...                                 ...
# 9313      2    48            Verbenal                            Verbenal
# 9314      1    38            Verbenal                            Verbenal
# 9315      1    38            Verbenal                            Verbenal
# 9316      1    48            Verbenal                            Verbenal
# 9317      2    48            Verbenal                            Verbenal
#
#                 Valor Moneda      Precio  ...  INSEGURIDAD  TERMINALES_BUS  \
# 0       $ 360.000.000      $   360000000  ...         0.52            0.01
# 1       $ 300.000.000      $   300000000  ...         0.52            0.01
# 2     $ 2.519.000.000      $  2519000000  ...         0.52            0.01
# 3       $ 239.000.000      $   239000000  ...         0.52            0.01
# 4     $ 1.600.000.000      $  1600000000  ...         0.52            0.01
# ...               ...    ...         ...  ...          ...             ...
# 9313    $ 250.000.000      $   250000000  ...         0.56            0.08
# 9314    $ 180.000.000      $   180000000  ...         0.56            0.08
# 9315    $ 180.000.000      $   180000000  ...         0.56            0.08
# 9316    $ 240.000.000      $   240000000  ...         0.56            0.08
# 9317    $ 240.000.000      $   240000000  ...         0.56            0.08
#
#       BARES_DISCO  OSCURO_PELIGROSO  BASURA_INADECUADA  RUIDO  SALARIO_MES  \
# 0            0.23              0.13               0.08   0.35   4034787.96
# 1            0.23              0.13               0.08   0.35   4034787.96
# 2            0.23              0.13               0.08   0.35   4034787.96
# 3            0.23              0.13               0.08   0.35   4034787.96
# 4            0.23              0.13               0.08   0.35   4034787.96
# ...           ...               ...                ...    ...          ...
# 9313         0.03              0.14               0.11   0.25   2445403.14
# 9314         0.03              0.14               0.11   0.25   2445403.14
# 9315         0.03              0.14               0.11   0.25   2445403.14
# 9316         0.03              0.14               0.11   0.25   2445403.14
# 9317         0.03              0.14               0.11   0.25   2445403.14
#
#       TIENE_ESCRITURA                      NOMBRE_ESTRATO  COD_UPZ_GRUPO
# 0                0.90  CHAPINERO: Pardo Rubio + Chapinero         816.00
# 1                0.90  CHAPINERO: Pardo Rubio + Chapinero         816.00
# 2                0.90  CHAPINERO: Pardo Rubio + Chapinero         816.00
# 3                0.90  CHAPINERO: Pardo Rubio + Chapinero         816.00
# 4                0.90  CHAPINERO: Pardo Rubio + Chapinero         816.00
# ...               ...                                 ...            ...
# 9313             0.87                            Verbenal           9.00
# 9314             0.87                            Verbenal           9.00
# 9315             0.87                            Verbenal           9.00
# 9316             0.87                            Verbenal           9.00
# 9317             0.87                            Verbenal           9.00
#
# [9318 rows x 24 columns]

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data= datos_ml, y = 'Precio_Millon')
plt.show()

# %%
datos_ml= datos_ml.query('Precio_Millon < 1050 & Precio_Millon > 60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9            Casa         Casa en venta en Zona Noroccidental             5
# 10    Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
#       Banos  Area              Barrio                                 UPZ  \
# 0         2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1         3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 3         1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 9         2   200  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 10        2    78  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# ...     ...   ...                 ...                                 ...
# 9313      2    48            Verbenal                            Verbenal
# 9314      1    38            Verbenal                            Verbenal
# 9315      1    38            Verbenal                            Verbenal
# 9316      1    48            Verbenal                            Verbenal
# 9317      2    48            Verbenal                            Verbenal
#
#               Valor Moneda     Precio  ...  TERMINALES_BUS  BARES_DISCO  \
# 0     $ 360.000.000      $  360000000  ...            0.01         0.23
# 1     $ 300.000.000      $  300000000  ...            0.01         0.23
# 3     $ 239.000.000      $  239000000  ...            0.01         0.23
# 9     $ 580.000.000      $  580000000  ...            0.01         0.23
# 10    $ 278.000.000      $  278000000  ...            0.01         0.23
# ...             ...    ...        ...  ...             ...          ...
# 9313  $ 250.000.000      $  250000000  ...            0.08         0.03
# 9314  $ 180.000.000      $  180000000  ...            0.08         0.03
# 9315  $ 180.000.000      $  180000000  ...            0.08         0.03
# 9316  $ 240.000.000      $  240000000  ...            0.08         0.03
# 9317  $ 240.000.000      $  240000000  ...            0.08         0.03
#
#       OSCURO_PELIGROSO  BASURA_INADECUADA  RUIDO  SALARIO_MES  \
# 0                 0.13               0.08   0.35   4034787.96
# 1                 0.13               0.08   0.35   4034787.96
# 3                 0.13               0.08   0.35   4034787.96
# 9                 0.13               0.08   0.35   4034787.96
# 10                0.13               0.08   0.35   4034787.96
# ...                ...                ...    ...          ...
# 9313              0.14               0.11   0.25   2445403.14
# 9314              0.14               0.11   0.25   2445403.14
# 9315              0.14               0.11   0.25   2445403.14
# 9316              0.14               0.11   0.25   2445403.14
# 9317              0.14               0.11   0.25   2445403.14
#
#       TIENE_ESCRITURA                      NOMBRE_ESTRATO  COD_UPZ_GRUPO  \
# 0                0.90  CHAPINERO: Pardo Rubio + Chapinero         816.00
# 1                0.90  CHAPINERO: Pardo Rubio + Chapinero         816.00
# 3                0.90  CHAPINERO: Pardo Rubio + Chapinero         816.00
# 9                0.90  CHAPINERO: Pardo Rubio + Chapinero         816.00
# 10               0.90  CHAPINERO: Pardo Rubio + Chapinero         816.00
# ...               ...                                 ...            ...
# 9313             0.87                            Verbenal           9.00
# 9314             0.87                            Verbenal           9.00
# 9315             0.87                            Verbenal           9.00
# 9316             0.87                            Verbenal           9.00
# 9317             0.87                            Verbenal           9.00
#
#       SALARIO_ANUAL_MI
# 0                48.42
# 1                48.42
# 3                48.42
# 9                48.42
# 10               48.42
# ...                ...
# 9313             29.34
# 9314             29.34
# 9315             29.34
# 9316             29.34
# 9317             29.34
#
# [8114 rows x 25 columns]

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data= datos_ml, y = 'Precio_Millon')
plt.show()

# %%
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml.head()
# Out:
# <ipython-input-130-38874a3ec607>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
#            Tipo                                 Descripcion  Habitaciones  \
# 0   Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1          Casa                      Casa en venta en Marly             3
# 3   Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9          Casa         Casa en venta en Zona Noroccidental             5
# 10  Apartamento  Apartamento en venta en Zona Noroccidental             3
#
#     Banos  Area              Barrio                                 UPZ  \
# 0       2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1       3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 3       1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 9       2   200  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 10      2    78  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#             Valor Moneda     Precio  ...  TERMINALES_BUS  BARES_DISCO  \
# 0   $ 360.000.000      $  360000000  ...            0.01         0.23
# 1   $ 300.000.000      $  300000000  ...            0.01         0.23
# 3   $ 239.000.000      $  239000000  ...            0.01         0.23
# 9   $ 580.000.000      $  580000000  ...            0.01         0.23
# 10  $ 278.000.000      $  278000000  ...            0.01         0.23
#
#     OSCURO_PELIGROSO  BASURA_INADECUADA  RUIDO  SALARIO_MES  TIENE_ESCRITURA  \
# 0               0.13               0.08   0.35   4034787.96             0.90
# 1               0.13               0.08   0.35   4034787.96             0.90
# 3               0.13               0.08   0.35   4034787.96             0.90
# 9               0.13               0.08   0.35   4034787.96             0.90
# 10              0.13               0.08   0.35   4034787.96             0.90
#
#                         NOMBRE_ESTRATO  COD_UPZ_GRUPO  SALARIO_ANUAL_MI
# 0   CHAPINERO: Pardo Rubio + Chapinero         816.00             48.42
# 1   CHAPINERO: Pardo Rubio + Chapinero         816.00             48.42
# 3   CHAPINERO: Pardo Rubio + Chapinero         816.00             48.42
# 9   CHAPINERO: Pardo Rubio + Chapinero         816.00             48.42
# 10  CHAPINERO: Pardo Rubio + Chapinero         816.00             48.42
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data= datos_ml, x='SALARIO_ANUAL_MI', y = 'Valor_m2_Millon')
plt.ylim((0, 15))
plt.show()

# %%
datos_ml.corr()
# Out:
#                    Habitaciones  Banos  Area  Precio_Millon  Valor_m2_Millon  \
# Habitaciones               1.00   0.44  0.03           0.18            -0.31
# Banos                      0.44   1.00  0.04           0.66            -0.04
# Area                       0.03   0.04  1.00           0.05            -0.04
# Precio_Millon              0.18   0.66  0.05           1.00             0.35
# Valor_m2_Millon           -0.31  -0.04 -0.04           0.35             1.00
# Valor_m2_barrio           -0.21   0.12 -0.04           0.41             0.48
# CONJUNTO_CERRADO          -0.12   0.15 -0.01           0.33             0.33
# INSEGURIDAD                0.13  -0.19 -0.00          -0.38            -0.37
# TERMINALES_BUS             0.09  -0.16 -0.01          -0.29            -0.29
# BARES_DISCO                0.11  -0.12 -0.01          -0.24            -0.22
# OSCURO_PELIGROSO           0.12  -0.21  0.01          -0.39            -0.35
# BASURA_INADECUADA          0.15  -0.19  0.01          -0.40            -0.41
# RUIDO                      0.14  -0.16 -0.00          -0.35            -0.36
# SALARIO_MES               -0.18   0.17 -0.01           0.42             0.45
# TIENE_ESCRITURA           -0.08   0.12 -0.01           0.22             0.24
# COD_UPZ_GRUPO             -0.12   0.00 -0.01           0.15             0.25
# SALARIO_ANUAL_MI          -0.18   0.17 -0.01           0.42             0.45
#
#                    Valor_m2_barrio  CONJUNTO_CERRADO  INSEGURIDAD  \
# Habitaciones                 -0.21             -0.12         0.13
# Banos                         0.12              0.15        -0.19
# Area                         -0.04             -0.01        -0.00
# Precio_Millon                 0.41              0.33        -0.38
# Valor_m2_Millon               0.48              0.33        -0.37
# Valor_m2_barrio               1.00              0.65        -0.66
# CONJUNTO_CERRADO              0.65              1.00        -0.84
# INSEGURIDAD                  -0.66             -0.84         1.00
# TERMINALES_BUS               -0.38             -0.30         0.51
# BARES_DISCO                  -0.41             -0.50         0.60
# OSCURO_PELIGROSO             -0.60             -0.66         0.75
# BASURA_INADECUADA            -0.69             -0.80         0.84
# RUIDO                        -0.66             -0.70         0.85
# SALARIO_MES                   0.82              0.81        -0.82
# TIENE_ESCRITURA               0.42              0.61        -0.56
# COD_UPZ_GRUPO                 0.41              0.09         0.00
# SALARIO_ANUAL_MI              0.82              0.81        -0.82
#
#                    TERMINALES_BUS  BARES_DISCO  OSCURO_PELIGROSO  \
# Habitaciones                 0.09         0.11              0.12
# Banos                       -0.16        -0.12             -0.21
# Area                        -0.01        -0.01              0.01
# Precio_Millon               -0.29        -0.24             -0.39
# Valor_m2_Millon             -0.29        -0.22             -0.35
# Valor_m2_barrio             -0.38        -0.41             -0.60
# CONJUNTO_CERRADO            -0.30        -0.50             -0.66
# INSEGURIDAD                  0.51         0.60              0.75
# TERMINALES_BUS               1.00         0.40              0.58
# BARES_DISCO                  0.40         1.00              0.49
# OSCURO_PELIGROSO             0.58         0.49              1.00
# BASURA_INADECUADA            0.52         0.44              0.82
# RUIDO                        0.68         0.60              0.65
# SALARIO_MES                 -0.51        -0.38             -0.76
# TIENE_ESCRITURA             -0.31        -0.26             -0.52
# COD_UPZ_GRUPO               -0.09         0.27             -0.01
# SALARIO_ANUAL_MI            -0.51        -0.38             -0.76
#
#                    BASURA_INADECUADA  RUIDO  SALARIO_MES  TIENE_ESCRITURA  \
# Habitaciones                    0.15   0.14        -0.18            -0.08
# Banos                          -0.19  -0.16         0.17             0.12
# Area                            0.01  -0.00        -0.01            -0.01
# Precio_Millon                  -0.40  -0.35         0.42             0.22
# Valor_m2_Millon                -0.41  -0.36         0.45             0.24
# Valor_m2_barrio                -0.69  -0.66         0.82             0.42
# CONJUNTO_CERRADO               -0.80  -0.70         0.81             0.61
# INSEGURIDAD                     0.84   0.85        -0.82            -0.56
# TERMINALES_BUS                  0.52   0.68        -0.51            -0.31
# BARES_DISCO                     0.44   0.60        -0.38            -0.26
# OSCURO_PELIGROSO                0.82   0.65        -0.76            -0.52
# BASURA_INADECUADA               1.00   0.73        -0.89            -0.50
# RUIDO                           0.73   1.00        -0.77            -0.62
# SALARIO_MES                    -0.89  -0.77         1.00             0.54
# TIENE_ESCRITURA                -0.50  -0.62         0.54             1.00
# COD_UPZ_GRUPO                  -0.21  -0.11         0.39             0.03
# SALARIO_ANUAL_MI               -0.89  -0.77         1.00             0.54
#
#                    COD_UPZ_GRUPO  SALARIO_ANUAL_MI
# Habitaciones               -0.12             -0.18
# Banos                       0.00              0.17
# Area                       -0.01             -0.01
# Precio_Millon               0.15              0.42
# Valor_m2_Millon             0.25              0.45
# Valor_m2_barrio             0.41              0.82
# CONJUNTO_CERRADO            0.09              0.81
# INSEGURIDAD                 0.00             -0.82
# TERMINALES_BUS             -0.09             -0.51
# BARES_DISCO                 0.27             -0.38
# OSCURO_PELIGROSO           -0.01             -0.76
# BASURA_INADECUADA          -0.21             -0.89
# RUIDO                      -0.11             -0.77
# SALARIO_MES                 0.39              1.00
# TIENE_ESCRITURA             0.03              0.54
# COD_UPZ_GRUPO               1.00              0.39
# SALARIO_ANUAL_MI            0.39              1.00

# %%
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = datos_ml[['COD_UPZ_GRUPO', 'Banos', 'Area', 'INSEGURIDAD', 'BARES_DISCO', 'OSCURO_PELIGROSO']]
y = datos_ml['Precio_Millon']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=99)

# %%
X_train
# Out:
#       COD_UPZ_GRUPO  Banos  Area  INSEGURIDAD  BARES_DISCO  OSCURO_PELIGROSO
# 4610          47.00      2    57         0.61         0.17              0.09
# 1118         816.00      2   110         0.52         0.23              0.13
# 7092          94.00      1    38         0.64         0.36              0.30
# 1326         802.00      3   122         0.58         0.11              0.13
# 931          816.00      1    44         0.52         0.23              0.13
# ...             ...    ...   ...          ...          ...               ...
# 2248          14.00      2    80         0.22         0.03              0.01
# 4031         803.00      2    58         0.42         0.02              0.01
# 6336          74.00      2    72         0.87         0.11              0.13
# 8342          98.00      5   126         0.70         0.37              0.08
# 5710          27.00      1    46         0.42         0.07              0.13
#
# [6085 rows x 6 columns]

# %%
X_test
# Out:
#       COD_UPZ_GRUPO  Banos  Area  INSEGURIDAD  BARES_DISCO  OSCURO_PELIGROSO
# 6158          21.00      3    71         0.39         0.09              0.09
# 1335         802.00      2    63         0.58         0.11              0.13
# 7728          85.00      1    47         0.94         0.19              0.24
# 9009          73.00      2    60         0.69         0.10              0.17
# 2509          14.00      2    91         0.22         0.03              0.01
# ...             ...    ...   ...          ...          ...               ...
# 9118          18.00      3    69         0.38         0.03              0.18
# 5158         101.00      2   140         0.60         0.21              0.05
# 6879          75.00      2    54         0.44         0.04              0.18
# 394          816.00      3   100         0.52         0.23              0.13
# 2545          14.00      3    76         0.22         0.03              0.01
#
# [2029 rows x 6 columns]

# %%
y_train
# Out:
# 4610   199.00
# 1118   730.00
# 7092   240.00
# 1326   420.00
# 931    144.00
#         ...
# 2248   490.00
# 4031   419.60
# 6336   280.00
# 8342   450.00
# 5710   210.00
# Name: Precio_Millon, Length: 6085, dtype: float64

# %%
y_test
# Out:
# 6158   230.00
# 1335   222.00
# 7728   131.00
# 9009   242.00
# 2509   730.00
#         ...
# 9118   310.00
# 5158   530.00
# 6879   210.00
# 394    525.00
# 2545   475.00
# Name: Precio_Millon, Length: 2029, dtype: float64

# %%
modelo = LinearRegression()

# %%
modelo.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict_test = modelo.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score
baseline_mae = mean_absolute_error(y_test, y_predict_test)
baseline_r2 = r2_score(y_test, y_predict_test)
print(baseline_mae, baseline_r2)
# Out:
# 115.04691795076899 0.5225926451679936

# %%
modelo.predict([[804, 2, 95, 0, 1, 0]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([362.30735212])
